# %%
# %matplotlib inline
import sys
sys.path.append('../main')
import main

# %%
main.run(debug=False)
# Out:
# [[{'id': 20, 'coordinate': [104.13259574816941, 30.693745498733723]},
#   {'id': 0,
#    'coordinate': [104.07506570814722, 30.663274810463378],
#    'sites': 6}],
#  [{'id': 50, 'coordinate': [104.09835110959511, 30.673409109612727]},
#   {'id': 0,
#    'coordinate': [104.07506570814722, 30.663274810463378],
#    'sites': 6}],
#  [{'id': 42, 'coordinate': [104.13838472780317, 30.700482539652533]},
#   {'id': 0,
#    'coordinate': [104.07506570814722, 30.663274810463378],
#    'sites': 6}],
#  [{'id': 73, 'coordinate': [104.1154043701103, 30.698214620588473]},
#   {'id': 0,
#    'coordinate': [104.07506570814722, 30.663274810463378],
#    'sites': 6}],
#  [{'id': 39, 'coordinate': [104.11187141858085, 30.695333271446234]},
#   {'id': 0,
#    'coordinate': [104.07506570814722, 30.663274810463378],
#    'sites': 6}],
#  [{'id': 1, 'coordinate': [104.11142409139215, 30.696316010928406]},
#   {'id': 0,
#    'coordinate': [104.07506570814722, 30.663274810463378],
#    'sites': 6}],
# ...
