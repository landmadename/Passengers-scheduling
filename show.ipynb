# %%
# %matplotlib inline
import main

# %%
main.run(debug=True, type='take')
# Out:
# [[{'id': 57, 'coordinate': [104.14042258489336, 30.63068593307582]},
#   {'id': 0,
#    'coordinate': [104.13543154416136, 30.63660357479714],
#    'sites': 6}],
#  [{'id': 15, 'coordinate': [104.13012732437011, 30.62477163385786]},
#   {'id': 0,
#    'coordinate': [104.13543154416136, 30.63660357479714],
#    'sites': 6}],
#  [{'id': 54, 'coordinate': [104.1472344450839, 30.643254536791083]},
#   {'id': 0,
#    'coordinate': [104.13543154416136, 30.63660357479714],
#    'sites': 6}],
#  [{'id': 37, 'coordinate': [104.13361544911479, 30.649823779035657]},
#   {'id': 0,
#    'coordinate': [104.13543154416136, 30.63660357479714],
#    'sites': 6}],
#  [{'id': 41, 'coordinate': [104.1241768523136, 30.64408119127224]},
#   {'id': 0,
#    'coordinate': [104.13543154416136, 30.63660357479714],
#    'sites': 6}],
#  [{'id': 78, 'coordinate': [104.11182320321909, 30.638898342527995]},
#   {'id': 0,
#    'coordinate': [104.13543154416136, 30.63660357479714],
#    'sites': 6}],
# ...
